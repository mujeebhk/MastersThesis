# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /Users/mohammedmujeeb/Google Drive/MastersThesis/Github/MastersThesis/CodeToSplitData/darknet
# sed: 1: "Makefile": invalid command code M
# sed: 1: "Makefile": invalid command code M
# sed: 1: "Makefile": invalid command code M

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# zsh:1: no such file or directory: /usr/local/cuda/bin/nvcc

# %%
# make darknet (build)
# !make
# Out:
# chmod +x *.sh

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /content
# Mounted at /content/gdrive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
#  AccessAnywhere.drawio	     MastersThesis
# 'Access Anywhere.gantter'    MobIOT
#  Akiya			     Personal
# 'Akiya Discussion.gsheet'    Pictures
#  archive		     Preparation
#  Archive		     Resume
#  Ashrin_Nida_ppf.rar	     SECBiometric.java
#  Boomerang		     Securience
# 'Broadcom Docs'		    'Self Improvement'
# 'Broadcom Payslip'	    'Untitled Diagram (1).drawio'
# 'Colab Notebooks'	    'Untitled Diagram.drawio'
# 'Deprecated LJMU Research'  'Untitled document.gdoc'
# 'Google Buzz'		    'untitled folder'
# 'IDs And Certs'		    'Virtual Background'
#  Immigration		    'Vocal Cord.gsheet'
#  Instatech		     Websequencediagrams.gdoc
#  Jayesh

# %%
# !cp /mydrive/MastersThesis/obj.zip ../

# %%
pwd
# Out:
# '/content/darknet'

# %%
# !pwd
# %cd darknet/
# Out:
# /content/darknet
# [Errno 20] Not a directory: 'darknet/'
# /content/darknet

# %%
# !unzip obj.zip -d data/
# Out:
# Archive:  obj.zip
#    creating: data/obj/
#   inflating: data/obj/P96-382_jpeg.rf.dbcfc7d9a116f97282240dc58c2c4d90.jpg
#   inflating: data/__MACOSX/obj/._P96-382_jpeg.rf.dbcfc7d9a116f97282240dc58c2c4d90.jpg
#   inflating: data/obj/P96-166_jpeg.rf.96c0a300273376d98de29cb4b1b43d00.txt
#   inflating: data/__MACOSX/obj/._P96-166_jpeg.rf.96c0a300273376d98de29cb4b1b43d00.txt
#   inflating: data/obj/P22-55_jpeg.rf.d210931c9a306951053aaa5a4f41a524.jpg
#   inflating: data/__MACOSX/obj/._P22-55_jpeg.rf.d210931c9a306951053aaa5a4f41a524.jpg
#   inflating: data/obj/P96-336_jpeg.rf.6c927f854bbc8c0ee05458edf9540fbb.jpg
#   inflating: data/__MACOSX/obj/._P96-336_jpeg.rf.6c927f854bbc8c0ee05458edf9540fbb.jpg
#   inflating: data/obj/P55-223_jpeg.rf.087ff794cd6b0141d2503ab9c89d432d.txt
#   inflating: data/__MACOSX/obj/._P55-223_jpeg.rf.087ff794cd6b0141d2503ab9c89d432d.txt
#   inflating: data/obj/P96-393_jpeg.rf.f4d62859f709d0fbe2436a76e47b2c08.jpg
# ...

# %%
# !cp /Users/mohammedmujeeb/Google Drive/MastersThesis/Github/MastersThesis/CodeToSplitData/VocalCordCyst.cfg ./cfg/
# Out:
# usage: cp [-R [-H | -L | -P]] [-fi | -n] [-apvXc] source_file target_file
#        cp [-R [-H | -L | -P]] [-fi | -n] [-apvXc] source_file ... target_directory

# %%
# !cp /Users/mohammedmujeeb/Google Drive/MastersThesis/Github/MastersThesis/CodeToSplitData/custom.names ./data/
# !cp /Users/mohammedmujeeb/Google Drive/MastersThesis/Github/MastersThesis/CodeToSplitData/detector.data ./data/
# Out:
# cp: /mydrive/MastersThesis/Github/MastersThesis/CodeToSplitData/custom.names: No such file or directory
# cp: /mydrive/MastersThesis/Github/MastersThesis/CodeToSplitData/detector.data: No such file or directory

# %%
# !cp /Users/mohammedmujeeb/Google Drive/MastersThesis/Github/MastersThesis/CodeToSplitData/train.txt ./data/
# !cp /Users/mohammedmujeeb/Google Drive/MastersThesis/Github/MastersThesis/CodeToSplitData/test.txt ./data/
# Out:
# cp: /mydrive/MastersThesis/Github/MastersThesis/CodeToSplitData/train.txt: No such file or directory
# cp: /mydrive/MastersThesis/Github/MastersThesis/CodeToSplitData/test.txt: No such file or directory

# %%
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights

# %%
# cp darknet53.conv.74 /mydrive/yolo_1/

# %%
# !./darknet detector train data/detector.data cfg/VocalCordCyst.cfg  -dont_show 2>&1 | tee TrainerLog.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000051, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000897, iou_loss = 0.000000, total_loss = 0.000897
#  total_bbox = 188226, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 16 Avg (IOU: 0.948145, GIOU: 0.947833), Class: 0.998783, Obj: 0.918524, No Obj: 0.001775, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.019619, iou_loss = 0.002463, total_loss = 0.022082
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 23 Avg (IOU: 0.774741, GIOU: 0.774742), Class: 0.998648, Obj: 0.378298, No Obj: 0.000489, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.216213, iou_loss = 0.046303, total_loss = 0.262516
#  total_bbox = 188228, rewritten_bbox = 0.000000 %
# ...

# %%
# !./darknet detector test data/detector.data cfg/VocalCordCyst.cfg /Users/mohammedmujeeb/Google Drive/MastersThesis/backup/VocalCordCyst_final.weights /Users/mohammedmujeeb/Google Drive/MastersThesis/gg.jpeg
# Out:
# zsh:1: permission denied: ./darknet

# %%
pwd
# Out:
# '/Users/mohammedmujeeb/Google Drive/MastersThesis/Github/MastersThesis/CodeToSplitData'

# %%
# !./darknet detect cfg/VocalCordCyst.cfg /mydrive/MastersThesis/backup/VocalCordCyst_final.weights /mydrive/MastersThesis/gg.jpeg
# Out:
# zsh:1: permission denied: ./darknet
